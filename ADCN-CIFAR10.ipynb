# %%
from utilsADCN import cifarLoaderAllChannels, plotPerformance
from ADCNbasic import ADCN
from ADCNmainloop import ADCNmain
from model import ConvAeCIFAR
import numpy as np
import pdb
import torch
import random
from torchvision import datasets, transforms

# %%
# random seed control
np.random.seed(0)
torch.manual_seed(0)
random.seed(0)

# %%
# convert data to torch.FloatTensor
# transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5,0.5,0.5))])
transform = transforms.ToTensor()

# load the training and test datasets
labeledData   = datasets.CIFAR10(root='data', train=False,download=True, transform=transform)
unlabeledData = datasets.CIFAR10(root='data', train=True, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataStream = cifarLoaderAllChannels(labeledData, unlabeledData, nEachClassSamples = 500)
# Out:
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  55000
# Number of unlabeled data batch:  55

# %%
dataStream.createDrift(nDrift = 4, taskList = [[0,5],[6,10],[11,15],[0,15]], taskType = 2)

# %%
device = torch.device('cuda:0')

# %%
allMetrics = []

# %%
nNodeInit  = 96  
nIn        = 768  
n_trials   = 5
batch_size = 16 #

# %%
for i_trial in range(0, n_trials):
    print('Trial: ', i_trial)
    ADCNnet         = ADCN(dataStream.nOutput, nInput = nIn, nHiddenNode = nNodeInit)
    ADCNnet.ADCNcnn = ConvAeCIFAR()
    ADCNnet, performanceHistory, allPerformance = ADCNmain(ADCNnet, dataStream, trainingBatchSize = batch_size, device = device)
    allMetrics.append(allPerformance)
# Out:
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  2204  centroids
# 0 -th batch
# Accuracy:  25.8
# 1 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.026927432045340538 ; Error bound warning:  0.4799738824367523 ; Error bound drift:  0.528351366519928
# Status: STABLE
# 2 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.032099414616823196 ; Error bound warning:  0.4802370071411133 ; Error bound drift:  0.5286411643028259
# Status: STABLE
# 3 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.015979936346411705 ; Error bound warning:  0.48162078857421875 ; Error bound drift:  0.5301643013954163
# Status: STABLE
# 4 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.033013734966516495 ; Error bound warning:  0.48455408215522766 ; Error bound drift:  0.5333933234214783
# Status: STABLE
# 5 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05582362785935402 ; Error bound warning:  0.4918862283229828 ; Error bound drift:  0.5414643883705139
# Status: STABLE
# 6 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024839287623763084 ; Error bound warning:  0.48969805240631104 ; Error bound drift:  0.5390557646751404
# Status: STABLE
# 7 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.026052748784422874 ; Error bound warning:  0.48611000180244446 ; Error bound drift:  0.5351060032844543
# Status: STABLE
# 8 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03705962002277374 ; Error bound warning:  0.4874591827392578 ; Error bound drift:  0.5365911722183228
# Status: STABLE
# 9 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027471423149108887 ; Error bound warning:  0.4870930016040802 ; Error bound drift:  0.5361880660057068
# Status: STABLE
# 10 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04740821197628975 ; Error bound warning:  0.4850706160068512 ; Error bound drift:  0.5339618921279907
# Status: STABLE
# Accuracy:  25.727272727272727
# 11 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.01796412654221058 ; Error bound warning:  0.48088565468788147 ; Error bound drift:  0.5293551087379456
# Status: STABLE
# 12 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03302547335624695 ; Error bound warning:  0.4791144132614136 ; Error bound drift:  0.527405321598053
# Status: STABLE
# 13 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.040409576147794724 ; Error bound warning:  0.48050251603126526 ; Error bound drift:  0.5289332866668701
# Status: STABLE
# 14 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03093159943819046 ; Error bound warning:  0.48063230514526367 ; Error bound drift:  0.5290761590003967
# Status: STABLE
# 15 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02522563934326172 ; Error bound warning:  0.4834548234939575 ; Error bound drift:  0.5321832299232483
# Status: STABLE
# 16 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03161246329545975 ; Error bound warning:  0.4835323393344879 ; Error bound drift:  0.5322685837745667
# Status: STABLE
# 17 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024917615577578545 ; Error bound warning:  0.4830308258533478 ; Error bound drift:  0.5317164063453674
# Status: STABLE
# 18 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.059987977147102356 ; Error bound warning:  0.47827014327049255 ; Error bound drift:  0.5264759063720703
# Status: STABLE
# 19 -th batch
# A cut point is detected cut:  1000
# H0 is NOT rejected, size: 0.027739480137825012 ; Error bound warning:  0.27487871050834656 ; Error bound drift:  0.3025842607021332
# Status: STABLE
# 20 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022964758798480034 ; Error bound warning:  0.4796484410762787 ; Error bound drift:  0.5279931426048279
# Status: STABLE
# Accuracy:  25.795238095238098
# 21 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0559099055826664 ; Error bound warning:  0.48350226879119873 ; Error bound drift:  0.5322355031967163
# Status: STABLE
# 22 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0603536032140255 ; Error bound warning:  0.4810762405395508 ; Error bound drift:  0.5295648574829102
# Status: STABLE
# 23 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04407782852649689 ; Error bound warning:  0.48182108998298645 ; Error bound drift:  0.5303848385810852
# Status: STABLE
# 24 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022593514993786812 ; Error bound warning:  0.48083004355430603 ; Error bound drift:  0.5292938351631165
# Status: STABLE
# 25 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025619864463806152 ; Error bound warning:  0.48042163252830505 ; Error bound drift:  0.5288442969322205
# Status: STABLE
# 26 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023102758452296257 ; Error bound warning:  0.477976530790329 ; Error bound drift:  0.5261527299880981
# Status: STABLE
# 27 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023660659790039062 ; Error bound warning:  0.4793744385242462 ; Error bound drift:  0.5276915431022644
# Status: STABLE
# 28 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023084545508027077 ; Error bound warning:  0.48224687576293945 ; Error bound drift:  0.5308534502983093
# Status: STABLE
# 29 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03746950253844261 ; Error bound warning:  0.48325538635253906 ; Error bound drift:  0.5319637656211853
# Status: STABLE
# 30 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0256195068359375 ; Error bound warning:  0.4831220209598541 ; Error bound drift:  0.531816840171814
# Status: STABLE
# Accuracy:  26.290322580645164
# 31 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.031197890639305115 ; Error bound warning:  0.4812260568141937 ; Error bound drift:  0.5297297835350037
# Status: STABLE
# 32 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.035305801779031754 ; Error bound warning:  0.4788428843021393 ; Error bound drift:  0.5271064043045044
# Status: STABLE
# 33 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027883106842637062 ; Error bound warning:  0.4772661626338959 ; Error bound drift:  0.5253707766532898
# Status: STABLE
# 34 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05965679883956909 ; Error bound warning:  0.4786122739315033 ; Error bound drift:  0.526852548122406
# Status: STABLE
# 35 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.035293661057949066 ; Error bound warning:  0.47879061102867126 ; Error bound drift:  0.5270488858222961
# Status: STABLE
# 36 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0327962264418602 ; Error bound warning:  0.4799652099609375 ; Error bound drift:  0.5283418893814087
# Status: STABLE
# 37 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03280728682875633 ; Error bound warning:  0.47922858595848083 ; Error bound drift:  0.5275309681892395
# Status: STABLE
# 38 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.040719758719205856 ; Error bound warning:  0.4822515547275543 ; Error bound drift:  0.5308586955070496
# Status: STABLE
# 39 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04041100665926933 ; Error bound warning:  0.4806957244873047 ; Error bound drift:  0.5291460156440735
# Status: STABLE
# 40 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0392485186457634 ; Error bound warning:  0.47860458493232727 ; Error bound drift:  0.5268441438674927
# Status: STABLE
# Accuracy:  26.43658536585366
# 41 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025354405865073204 ; Error bound warning:  0.4814006984233856 ; Error bound drift:  0.5299220085144043
# Status: STABLE
# 42 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02914191037416458 ; Error bound warning:  0.4812706708908081 ; Error bound drift:  0.5297788977622986
# Status: STABLE
# 43 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03680774196982384 ; Error bound warning:  0.4796210825443268 ; Error bound drift:  0.5279631018638611
# Status: STABLE
# 44 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03151619806885719 ; Error bound warning:  0.47910764813423157 ; Error bound drift:  0.5273978114128113
# Status: STABLE
# 45 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.046600740402936935 ; Error bound warning:  0.48048773407936096 ; Error bound drift:  0.5289170742034912
# Status: STABLE
# 46 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024549325928092003 ; Error bound warning:  0.4782707691192627 ; Error bound drift:  0.5264766812324524
# Status: STABLE
# 47 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03570934757590294 ; Error bound warning:  0.4786948263645172 ; Error bound drift:  0.5269434452056885
# Status: STABLE
# 48 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025164447724819183 ; Error bound warning:  0.482317179441452 ; Error bound drift:  0.5309309363365173
# Status: STABLE
# 49 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03711836785078049 ; Error bound warning:  0.4817741811275482 ; Error bound drift:  0.5303331017494202
# Status: STABLE
# 50 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023859545588493347 ; Error bound warning:  0.4812847077846527 ; Error bound drift:  0.5297942757606506
# Status: STABLE
# Accuracy:  26.44509803921569
# 51 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04566328600049019 ; Error bound warning:  0.482240229845047 ; Error bound drift:  0.5308462977409363
# Status: STABLE
#
#
# === Performance result ===
# Accuracy:  26.47884615384616 (+/-) 1.313881000708842
# ARI:  0.04833647361005423
# NMI:  0.07822514336493096
# F1 score:  0.26094801428055314
# Precision:  0.26727450033652916
# Recall:  0.26478846153846153
# Testing Time:  1.1519812849851756 (+/-) 0.06267455374674441
# Training Time:  771.2177991912915 (+/-) 0.6229380349620833
#
#
# === Average network evolution ===
# Number of layer:  1.0 (+/-) 0.0
# Total hidden node:  397.0 (+/-) 0.0
# Number of cluster:  2565.0 (+/-) 122.68236033946175
#
#
# === Final network structure ===
# basicAE(
#   (linear): Linear(in_features=768, out_features=397, bias=True)
#   (activation): ReLU(inplace)
# )
# No. of AE inputs : 768
# No. of AE nodes : 397
# No. of AE parameters : 306061
# Trial:  1
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  2133  centroids
# 0 -th batch
# Accuracy:  27.3
# 1 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02445979416370392 ; Error bound warning:  0.43670687079429626 ; Error bound drift:  0.48072338104248047
# Status: STABLE
# 2 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02874860167503357 ; Error bound warning:  0.4376179277896881 ; Error bound drift:  0.4817262887954712
# Status: STABLE
# 3 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.013722176663577557 ; Error bound warning:  0.4363173544406891 ; Error bound drift:  0.48029470443725586
# Status: STABLE
# 4 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03076699562370777 ; Error bound warning:  0.441368967294693 ; Error bound drift:  0.485855370759964
# Status: STABLE
# 5 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04992487654089928 ; Error bound warning:  0.44768115878105164 ; Error bound drift:  0.4928038418292999
# Status: STABLE
# 6 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02142277918756008 ; Error bound warning:  0.4459885358810425 ; Error bound drift:  0.4909406006336212
# Status: STABLE
# 7 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023213492706418037 ; Error bound warning:  0.44203662872314453 ; Error bound drift:  0.48659035563468933
# Status: STABLE
# 8 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.033361878246068954 ; Error bound warning:  0.44272327423095703 ; Error bound drift:  0.4873462915420532
# Status: STABLE
# 9 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025956593453884125 ; Error bound warning:  0.44340062141418457 ; Error bound drift:  0.4880918264389038
# Status: STABLE
# 10 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04353497922420502 ; Error bound warning:  0.4431372582912445 ; Error bound drift:  0.4878019392490387
# Status: STABLE
# Accuracy:  25.745454545454546
# 11 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.016966503113508224 ; Error bound warning:  0.43846094608306885 ; Error bound drift:  0.482654333114624
# Status: STABLE
# 12 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.030354084447026253 ; Error bound warning:  0.4377168118953705 ; Error bound drift:  0.4818352460861206
# Status: STABLE
# 13 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03658823296427727 ; Error bound warning:  0.4376180171966553 ; Error bound drift:  0.4817264974117279
# Status: STABLE
# 14 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027280816808342934 ; Error bound warning:  0.43867504596710205 ; Error bound drift:  0.48288998007774353
# Status: STABLE
# 15 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022693553939461708 ; Error bound warning:  0.43937763571739197 ; Error bound drift:  0.483663409948349
# Status: STABLE
# 16 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027591226622462273 ; Error bound warning:  0.43941840529441833 ; Error bound drift:  0.4837082624435425
# Status: STABLE
# 17 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022289415821433067 ; Error bound warning:  0.4393904209136963 ; Error bound drift:  0.483677476644516
# Status: STABLE
# 18 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.054252397269010544 ; Error bound warning:  0.4363313913345337 ; Error bound drift:  0.4803100824356079
# Status: STABLE
# 19 -th batch
# A cut point is detected cut:  1000
# H0 is NOT rejected, size: 0.025703810155391693 ; Error bound warning:  0.2504756450653076 ; Error bound drift:  0.27572154998779297
# Status: STABLE
# 20 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.020172009244561195 ; Error bound warning:  0.43794456124305725 ; Error bound drift:  0.48208585381507874
# Status: STABLE
# Accuracy:  25.699999999999996
# 21 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.050932396203279495 ; Error bound warning:  0.44203901290893555 ; Error bound drift:  0.48659300804138184
# Status: STABLE
# 22 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.053911108523607254 ; Error bound warning:  0.43715569376945496 ; Error bound drift:  0.48121750354766846
# Status: STABLE
# 23 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03932814300060272 ; Error bound warning:  0.4372393786907196 ; Error bound drift:  0.48130956292152405
# Status: STABLE
# 24 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.01976614259183407 ; Error bound warning:  0.4369278848171234 ; Error bound drift:  0.4809666872024536
# Status: STABLE
# 25 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023975640535354614 ; Error bound warning:  0.43545636534690857 ; Error bound drift:  0.47934690117836
# Status: STABLE
# 26 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.021372301504015923 ; Error bound warning:  0.43348073959350586 ; Error bound drift:  0.47717222571372986
# Status: STABLE
# 27 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.021299107000231743 ; Error bound warning:  0.4375919997692108 ; Error bound drift:  0.48169779777526855
# Status: STABLE
# 28 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.021471960470080376 ; Error bound warning:  0.440655916929245 ; Error bound drift:  0.48507046699523926
# Status: STABLE
# 29 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0344250462949276 ; Error bound warning:  0.4391932487487793 ; Error bound drift:  0.4834604263305664
# Status: STABLE
# 30 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022707976400852203 ; Error bound warning:  0.4382498264312744 ; Error bound drift:  0.482421875
# Status: STABLE
# Accuracy:  26.093548387096778
# 31 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.026936568319797516 ; Error bound warning:  0.43649718165397644 ; Error bound drift:  0.4804926812648773
# Status: STABLE
# 32 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03221698850393295 ; Error bound warning:  0.43462610244750977 ; Error bound drift:  0.47843292355537415
# Status: STABLE
# 33 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024597683921456337 ; Error bound warning:  0.43363091349601746 ; Error bound drift:  0.47733744978904724
# Status: STABLE
# 34 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05401558801531792 ; Error bound warning:  0.4340420067310333 ; Error bound drift:  0.477789968252182
# Status: STABLE
# 35 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03155406937003136 ; Error bound warning:  0.43400391936302185 ; Error bound drift:  0.4777480661869049
# Status: STABLE
# 36 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.029144948348402977 ; Error bound warning:  0.434360533952713 ; Error bound drift:  0.47814062237739563
# Status: STABLE
# 37 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0283218864351511 ; Error bound warning:  0.4315744936466217 ; Error bound drift:  0.47507381439208984
# Status: STABLE
# 38 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.037175387144088745 ; Error bound warning:  0.43413224816322327 ; Error bound drift:  0.4778893291950226
# Status: STABLE
# 39 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03617080673575401 ; Error bound warning:  0.4340148866176605 ; Error bound drift:  0.47776007652282715
# Status: STABLE
# 40 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03660889342427254 ; Error bound warning:  0.4342345893383026 ; Error bound drift:  0.47800198197364807
# Status: STABLE
# Accuracy:  26.404878048780485
# 41 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022426411509513855 ; Error bound warning:  0.4371406137943268 ; Error bound drift:  0.4812009632587433
# Status: STABLE
# 42 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02600320242345333 ; Error bound warning:  0.4366140365600586 ; Error bound drift:  0.48062121868133545
# Status: STABLE
# 43 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03299489989876747 ; Error bound warning:  0.4348820447921753 ; Error bound drift:  0.4787146747112274
# Status: STABLE
# 44 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.028354868292808533 ; Error bound warning:  0.4340820014476776 ; Error bound drift:  0.47783398628234863
# Status: STABLE
# 45 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.041134681552648544 ; Error bound warning:  0.43553707003593445 ; Error bound drift:  0.4794357120990753
# Status: STABLE
# 46 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02169615775346756 ; Error bound warning:  0.43159329891204834 ; Error bound drift:  0.47509443759918213
# Status: STABLE
# 47 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03148694708943367 ; Error bound warning:  0.43170222640037537 ; Error bound drift:  0.4752143621444702
# Status: STABLE
# 48 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.021681122481822968 ; Error bound warning:  0.4362521171569824 ; Error bound drift:  0.4802228510379791
# Status: STABLE
# 49 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03382902964949608 ; Error bound warning:  0.4362885653972626 ; Error bound drift:  0.4802628755569458
# Status: STABLE
# 50 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.021211542189121246 ; Error bound warning:  0.4333146810531616 ; Error bound drift:  0.4769892990589142
# Status: STABLE
# Accuracy:  26.447058823529414
# 51 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0404735691845417 ; Error bound warning:  0.4338010847568512 ; Error bound drift:  0.4775247573852539
# Status: STABLE
#
#
# === Performance result ===
# Accuracy:  26.44615384615385 (+/-) 1.3325022064437697
# ARI:  0.04930132244973628
# NMI:  0.07897958593534678
# F1 score:  0.26024255489918996
# Precision:  0.2656275573634466
# Recall:  0.26446153846153847
# Testing Time:  0.8227619941417987 (+/-) 0.05796095171619091
# Training Time:  549.167947452802 (+/-) 0.5697258433334246
#
#
# === Average network evolution ===
# Number of layer:  1.0 (+/-) 0.0
# Total hidden node:  267.0 (+/-) 0.0
# Number of cluster:  2498.923076923077 (+/-) 150.60708510173166
#
#
# === Final network structure ===
# basicAE(
#   (linear): Linear(in_features=768, out_features=267, bias=True)
#   (activation): ReLU(inplace)
# )
# No. of AE inputs : 768
# No. of AE nodes : 267
# No. of AE parameters : 206091
# Trial:  2
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  2192  centroids
# 0 -th batch
# Accuracy:  26.6
# 1 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023143185302615166 ; Error bound warning:  0.42593780159950256 ; Error bound drift:  0.4688689410686493
# Status: STABLE
# 2 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.028432244434952736 ; Error bound warning:  0.4281299114227295 ; Error bound drift:  0.4712819755077362
# Status: STABLE
# 3 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.013325545005500317 ; Error bound warning:  0.4285386800765991 ; Error bound drift:  0.47173190116882324
# Status: STABLE
# 4 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.028757542371749878 ; Error bound warning:  0.43341705203056335 ; Error bound drift:  0.47710204124450684
# Status: STABLE
# 5 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04920141026377678 ; Error bound warning:  0.4381982088088989 ; Error bound drift:  0.48236513137817383
# Status: STABLE
# 6 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02092309482395649 ; Error bound warning:  0.4351464807987213 ; Error bound drift:  0.4790057837963104
# Status: STABLE
# 7 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022661441937088966 ; Error bound warning:  0.43295708298683167 ; Error bound drift:  0.4765957295894623
# Status: STABLE
# 8 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03275369480252266 ; Error bound warning:  0.4345080852508545 ; Error bound drift:  0.47830304503440857
# Status: STABLE
# 9 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024705814197659492 ; Error bound warning:  0.4357242286205292 ; Error bound drift:  0.47964170575141907
# Status: STABLE
# 10 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.042797986418008804 ; Error bound warning:  0.43471238017082214 ; Error bound drift:  0.47852790355682373
# Status: STABLE
# Accuracy:  25.50909090909091
# 11 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.016113944351673126 ; Error bound warning:  0.42995941638946533 ; Error bound drift:  0.47329583764076233
# Status: STABLE
# 12 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02921297587454319 ; Error bound warning:  0.4278169572353363 ; Error bound drift:  0.47093749046325684
# Status: STABLE
# 13 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.035303518176078796 ; Error bound warning:  0.4282233715057373 ; Error bound drift:  0.47138485312461853
# Status: STABLE
# 14 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027100658044219017 ; Error bound warning:  0.42966732382774353 ; Error bound drift:  0.4729743003845215
# Status: STABLE
# 15 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022428961470723152 ; Error bound warning:  0.4325633943080902 ; Error bound drift:  0.4761623442173004
# Status: STABLE
# 16 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027122296392917633 ; Error bound warning:  0.43391475081443787 ; Error bound drift:  0.47764983773231506
# Status: STABLE
# 17 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.021204380318522453 ; Error bound warning:  0.4332461357116699 ; Error bound drift:  0.4769138991832733
# Status: STABLE
# 18 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05320000648498535 ; Error bound warning:  0.42930734157562256 ; Error bound drift:  0.4725780785083771
# Status: STABLE
# 19 -th batch
# A cut point is detected cut:  1000
# H0 is NOT rejected, size: 0.024896612390875816 ; Error bound warning:  0.2465129941701889 ; Error bound drift:  0.27135947346687317
# Status: STABLE
# 20 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.019614873453974724 ; Error bound warning:  0.42948055267333984 ; Error bound drift:  0.47276878356933594
# Status: STABLE
# Accuracy:  25.666666666666668
# 21 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04921382665634155 ; Error bound warning:  0.43511685729026794 ; Error bound drift:  0.4789731204509735
# Status: STABLE
# 22 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05312493070960045 ; Error bound warning:  0.4307667911052704 ; Error bound drift:  0.47418463230133057
# Status: STABLE
# 23 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03951411321759224 ; Error bound warning:  0.4305931627750397 ; Error bound drift:  0.4739935100078583
# Status: STABLE
# 24 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.01932409591972828 ; Error bound warning:  0.43048858642578125 ; Error bound drift:  0.4738783538341522
# Status: STABLE
# 25 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022914407774806023 ; Error bound warning:  0.42832812666893005 ; Error bound drift:  0.4715001881122589
# Status: STABLE
# 26 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.019346842542290688 ; Error bound warning:  0.4266703426837921 ; Error bound drift:  0.46967533230781555
# Status: STABLE
# 27 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.020628197118639946 ; Error bound warning:  0.43133237957954407 ; Error bound drift:  0.4748072624206543
# Status: STABLE
# 28 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02087036333978176 ; Error bound warning:  0.43380868434906006 ; Error bound drift:  0.47753313183784485
# Status: STABLE
# 29 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03341269493103027 ; Error bound warning:  0.43256881833076477 ; Error bound drift:  0.47616827487945557
# Status: STABLE
# 30 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02182152308523655 ; Error bound warning:  0.4318973124027252 ; Error bound drift:  0.47542908787727356
# Status: STABLE
# Accuracy:  26.045161290322582
# 31 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.026345496997237206 ; Error bound warning:  0.4304462969303131 ; Error bound drift:  0.4738318622112274
# Status: STABLE
# 32 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03231210634112358 ; Error bound warning:  0.42914438247680664 ; Error bound drift:  0.4723987281322479
# Status: STABLE
# 33 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023527735844254494 ; Error bound warning:  0.42721128463745117 ; Error bound drift:  0.4702707827091217
# Status: STABLE
# 34 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05199385806918144 ; Error bound warning:  0.4276237189769745 ; Error bound drift:  0.47072479128837585
# Status: STABLE
# 35 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.031446754932403564 ; Error bound warning:  0.42746543884277344 ; Error bound drift:  0.4705505669116974
# Status: STABLE
# 36 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.028317006304860115 ; Error bound warning:  0.42891284823417664 ; Error bound drift:  0.4721437990665436
# Status: STABLE
# 37 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027900276705622673 ; Error bound warning:  0.4273470938205719 ; Error bound drift:  0.4704202711582184
# Status: STABLE
# 38 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.036404091864824295 ; Error bound warning:  0.4304029643535614 ; Error bound drift:  0.47378411889076233
# Status: STABLE
# 39 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03610140085220337 ; Error bound warning:  0.4299670159816742 ; Error bound drift:  0.47330430150032043
# Status: STABLE
# 40 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03505336493253708 ; Error bound warning:  0.42937764525413513 ; Error bound drift:  0.47265544533729553
# Status: STABLE
# Accuracy:  26.21951219512195
# 41 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02161942608654499 ; Error bound warning:  0.4323548376560211 ; Error bound drift:  0.4759328067302704
# Status: STABLE
# 42 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02540642023086548 ; Error bound warning:  0.4329594075679779 ; Error bound drift:  0.47659826278686523
# Status: STABLE
# 43 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.031726304441690445 ; Error bound warning:  0.4311027228832245 ; Error bound drift:  0.4745544195175171
# Status: STABLE
# 44 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027033256366848946 ; Error bound warning:  0.4299651086330414 ; Error bound drift:  0.4733021557331085
# Status: STABLE
# 45 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.039633944630622864 ; Error bound warning:  0.43069204688072205 ; Error bound drift:  0.4741023778915405
# Status: STABLE
# 46 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.021260343492031097 ; Error bound warning:  0.42788949608802795 ; Error bound drift:  0.47101733088493347
# Status: STABLE
# 47 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03105073608458042 ; Error bound warning:  0.4291474521160126 ; Error bound drift:  0.47240209579467773
# Status: STABLE
# 48 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02150842361152172 ; Error bound warning:  0.4334881007671356 ; Error bound drift:  0.47718027234077454
# Status: STABLE
# 49 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.032599419355392456 ; Error bound warning:  0.43241655826568604 ; Error bound drift:  0.47600075602531433
# Status: STABLE
# 50 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.019937671720981598 ; Error bound warning:  0.43066978454589844 ; Error bound drift:  0.47407785058021545
# Status: STABLE
# Accuracy:  26.345098039215685
# 51 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.039778005331754684 ; Error bound warning:  0.43223240971565247 ; Error bound drift:  0.47579801082611084
# Status: STABLE
#
#
# === Performance result ===
# Accuracy:  26.371153846153845 (+/-) 1.360760044757445
# ARI:  0.04878759687919042
# NMI:  0.07782935294945784
# F1 score:  0.25831735510927506
# Precision:  0.2645179050689233
# Recall:  0.26371153846153844
# Testing Time:  0.7317267656326294 (+/-) 0.047467759002249206
# Training Time:  494.5130018958679 (+/-) 0.49866536829979363
#
#
# === Average network evolution ===
# Number of layer:  1.0 (+/-) 0.0
# Total hidden node:  218.0 (+/-) 0.0
# Number of cluster:  2626.5576923076924 (+/-) 172.6970906910018
#
#
# === Final network structure ===
# basicAE(
#   (linear): Linear(in_features=768, out_features=218, bias=True)
#   (activation): ReLU(inplace)
# )
# No. of AE inputs : 768
# No. of AE nodes : 218
# No. of AE parameters : 168410
# Trial:  3
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# ...
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  2090  centroids
# 0 -th batch
# Accuracy:  30.1
# 1 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.028273308649659157 ; Error bound warning:  0.4945056736469269 ; Error bound drift:  0.5443479418754578
# Status: STABLE
# 2 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.033381346613168716 ; Error bound warning:  0.49390944838523865 ; Error bound drift:  0.5436916351318359
# Status: STABLE
# 3 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.01581004448235035 ; Error bound warning:  0.49338653683662415 ; Error bound drift:  0.54311603307724
# Status: STABLE
# 4 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03209618106484413 ; Error bound warning:  0.5009763240814209 ; Error bound drift:  0.5514706969261169
# Status: STABLE
# 5 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05424472689628601 ; Error bound warning:  0.5072864294052124 ; Error bound drift:  0.5584167838096619
# Status: STABLE
# 6 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02497568167746067 ; Error bound warning:  0.5039967894554138 ; Error bound drift:  0.5547956824302673
# Status: STABLE
# 7 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.026540962979197502 ; Error bound warning:  0.5029561519622803 ; Error bound drift:  0.5536500811576843
# Status: STABLE
# 8 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.039713770151138306 ; Error bound warning:  0.5037680268287659 ; Error bound drift:  0.5545437932014465
# Status: STABLE
# 9 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.029195070266723633 ; Error bound warning:  0.5045686364173889 ; Error bound drift:  0.5554251074790955
# Status: STABLE
# 10 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.048546601086854935 ; Error bound warning:  0.5041904449462891 ; Error bound drift:  0.5550087690353394
# Status: STABLE
# Accuracy:  27.900000000000002
# 11 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.020895762369036674 ; Error bound warning:  0.4992847442626953 ; Error bound drift:  0.5496086478233337
# Status: STABLE
# 12 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03295096382498741 ; Error bound warning:  0.497468501329422 ; Error bound drift:  0.5476093888282776
# Status: STABLE
# 13 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04064187407493591 ; Error bound warning:  0.4988487958908081 ; Error bound drift:  0.5491287708282471
# Status: STABLE
# 14 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.033278774470090866 ; Error bound warning:  0.4994991719722748 ; Error bound drift:  0.5498446822166443
# Status: STABLE
# 15 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.032970502972602844 ; Error bound warning:  0.5015177130699158 ; Error bound drift:  0.5520667433738708
# Status: STABLE
# 16 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03998129442334175 ; Error bound warning:  0.5030921697616577 ; Error bound drift:  0.5537998080253601
# Status: STABLE
# 17 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025950303301215172 ; Error bound warning:  0.5039476752281189 ; Error bound drift:  0.5547415614128113
# Status: STABLE
# 18 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.060142647475004196 ; Error bound warning:  0.5009439587593079 ; Error bound drift:  0.5514350533485413
# Status: STABLE
# 19 -th batch
# A cut point is detected cut:  1000
# H0 is NOT rejected, size: 0.029016317799687386 ; Error bound warning:  0.28754833340644836 ; Error bound drift:  0.31653085350990295
# Status: STABLE
# 20 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02364133857190609 ; Error bound warning:  0.5010710954666138 ; Error bound drift:  0.5515751242637634
# Status: STABLE
# Accuracy:  28.11904761904762
# 21 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.057250913232564926 ; Error bound warning:  0.5052126049995422 ; Error bound drift:  0.5561339855194092
# Status: STABLE
# 22 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.06324220448732376 ; Error bound warning:  0.5013084411621094 ; Error bound drift:  0.5518363118171692
# Status: STABLE
# 23 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.044149238616228104 ; Error bound warning:  0.5023256540298462 ; Error bound drift:  0.5529561638832092
# Status: STABLE
# 24 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025798926129937172 ; Error bound warning:  0.5051635503768921 ; Error bound drift:  0.5560800433158875
# Status: STABLE
# 25 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02690424770116806 ; Error bound warning:  0.5034253597259521 ; Error bound drift:  0.5541666150093079
# Status: STABLE
# 26 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024384556338191032 ; Error bound warning:  0.5005199909210205 ; Error bound drift:  0.5509684085845947
# Status: STABLE
# 27 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025065293535590172 ; Error bound warning:  0.5043110847473145 ; Error bound drift:  0.5551415681838989
# Status: STABLE
# 28 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02930927835404873 ; Error bound warning:  0.5082548260688782 ; Error bound drift:  0.5594828128814697
# Status: STABLE
# 29 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.036643512547016144 ; Error bound warning:  0.5072773098945618 ; Error bound drift:  0.5584068298339844
# Status: STABLE
# 30 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025762878358364105 ; Error bound warning:  0.5070960521697998 ; Error bound drift:  0.5582072734832764
# Status: STABLE
# Accuracy:  28.503225806451614
# 31 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.032670099288225174 ; Error bound warning:  0.5036981701850891 ; Error bound drift:  0.554466962814331
# Status: STABLE
# 32 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.037393201142549515 ; Error bound warning:  0.5028787851333618 ; Error bound drift:  0.5535649061203003
# Status: STABLE
# 33 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.028446944430470467 ; Error bound warning:  0.5029104948043823 ; Error bound drift:  0.5535997748374939
# Status: STABLE
# 34 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.06041291356086731 ; Error bound warning:  0.5025821328163147 ; Error bound drift:  0.5532384514808655
# Status: STABLE
# 35 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.034905802458524704 ; Error bound warning:  0.5040855407714844 ; Error bound drift:  0.554893434047699
# Status: STABLE
# 36 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03489954397082329 ; Error bound warning:  0.504203200340271 ; Error bound drift:  0.5550228953361511
# Status: STABLE
# 37 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03555917367339134 ; Error bound warning:  0.5024663209915161 ; Error bound drift:  0.5531108975410461
# Status: STABLE
# 38 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04501214623451233 ; Error bound warning:  0.5060011744499207 ; Error bound drift:  0.557002067565918
# Status: STABLE
# 39 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03959809988737106 ; Error bound warning:  0.5046138763427734 ; Error bound drift:  0.5554749369621277
# Status: STABLE
# 40 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.044730667024850845 ; Error bound warning:  0.5033264756202698 ; Error bound drift:  0.5540578365325928
# Status: STABLE
# Accuracy:  28.546341463414635
# 41 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025878071784973145 ; Error bound warning:  0.5061033368110657 ; Error bound drift:  0.5571145415306091
# Status: STABLE
# 42 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.029660167172551155 ; Error bound warning:  0.5066940188407898 ; Error bound drift:  0.5577647686004639
# Status: STABLE
# 43 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03923965245485306 ; Error bound warning:  0.5067002177238464 ; Error bound drift:  0.5577715039253235
# Status: STABLE
# 44 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03361745551228523 ; Error bound warning:  0.5080052018165588 ; Error bound drift:  0.5592080950737
# Status: STABLE
# 45 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04555097222328186 ; Error bound warning:  0.5091922879219055 ; Error bound drift:  0.5605148077011108
# Status: STABLE
# 46 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02498711831867695 ; Error bound warning:  0.5062422752380371 ; Error bound drift:  0.5572674870491028
# Status: STABLE
# 47 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03823934122920036 ; Error bound warning:  0.5051386952400208 ; Error bound drift:  0.5560526847839355
# Status: STABLE
# 48 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024807756766676903 ; Error bound warning:  0.5107356905937195 ; Error bound drift:  0.5622137188911438
# Status: STABLE
# 49 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03987766057252884 ; Error bound warning:  0.5089743733406067 ; Error bound drift:  0.5602749586105347
# Status: STABLE
# 50 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024236982688307762 ; Error bound warning:  0.5079826712608337 ; Error bound drift:  0.5591832399368286
# Status: STABLE
# Accuracy:  28.594117647058823
# 51 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04902704432606697 ; Error bound warning:  0.5085203051567078 ; Error bound drift:  0.5597750544548035
# Status: STABLE
#
#
# === Performance result ===
# Accuracy:  28.607692307692307 (+/-) 1.337167809767828
# ARI:  0.06504677597780581
# NMI:  0.10162462649296809
# F1 score:  0.2823921057203628
# Precision:  0.2851072907284917
# Recall:  0.28607692307692306
# Testing Time:  1.2473968450839703 (+/-) 0.060748759842356934
# Training Time:  813.1648069482583 (+/-) 0.4576363579504105
#
#
# === Average network evolution ===
# Number of layer:  1.0 (+/-) 0.0
# Total hidden node:  489.0 (+/-) 0.0
# Number of cluster:  2400.75 (+/-) 104.47154102728352
#
#
# === Final network structure ===
# basicAE(
#   (linear): Linear(in_features=768, out_features=489, bias=True)
#   (activation): ReLU(inplace)
# )
# No. of AE inputs : 768
# No. of AE nodes : 489
# No. of AE parameters : 376809

# %%
# all results

# 0: accuracy
# 1: ARI
# 2: NMI
# 3: f1_score
# 4: precision_score
# 5: recall_score
# 6: training_time
# 7: testingTime
# 8: nHiddenLayer
# 9: nHiddenNode
# 10: nCluster

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance KMNIST ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('ARI: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('NMI: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('F1 score: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Precision: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Recall: ', meanResults[5].item(), '(+/-)',stdResults[5].item())
print('Training time: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Testing time: ', meanResults[7].item(), '(+/-)',stdResults[7].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[8].item(), '(+/-)',stdResults[8].item())
print('Number of features: ', meanResults[9].item(), '(+/-)',stdResults[9].item())
print('Number of clusters: ', meanResults[10].item(), '(+/-)',stdResults[10].item())
# Out:
# ========== Performance KMNIST ==========
# Preq Accuracy:  26.85 (+/-) 0.88
# ARI:  0.05 (+/-) 0.01
# NMI:  0.08 (+/-) 0.01
# F1 score:  0.26 (+/-) 0.01
# Precision:  0.27 (+/-) 0.01
# Recall:  0.27 (+/-) 0.01
# Training time:  669.47 (+/-) 125.35
# Testing time:  1.0 (+/-) 0.2
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  352.0 (+/-) 97.31
# Number of clusters:  2739.4 (+/-) 109.91
