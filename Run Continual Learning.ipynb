# %%
# %run ADCN-RMNIST-multiTask.ipynb
# Out:
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  65000
# Number of unlabeled data batch:  65
# Number of task:  4
# Number of labeled data per task:  1250
# Number of unlabeled data per task:  15000
# Number of unlabeled data batch per task:  15
# Number of unlabeled data test:  4000
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  644  centroids
# 1 -th batch 0 -th task
# Accuracy:  71.7
# 2 -th batch 0 -th task
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.08347757160663605 ; Error bound warning:  0.6001685261726379 ; Error bound drift:  0.6606608033180237
# Status: STABLE
# 3 -th batch 0 -th task
# ...

# %%
# %run ADCN-PMNIST-multiTask.ipynb
# Out:
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  65000
# Number of unlabeled data batch:  65
# Number of task:  4
# Number of labeled data per task:  1250
# Number of unlabeled data per task:  15000
# Number of unlabeled data batch per task:  15
# Number of unlabeled data test:  4000
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  612  centroids
# 1 -th batch 0 -th task
# Accuracy:  64.4
# 2 -th batch 0 -th task
# A cut point is detected cut:  500
# ...

# %%
# %run ADCN-splitMNIST.ipynb
# Out:
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  65000
# Number of unlabeled data batch:  65
# Number of task:  5
# Number of labeled data per task:  1000
# Number of unlabeled data per task:  12000
# Number of unlabeled data batch per task:  12
# Number of unlabeled data test:  5000
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  483  centroids
# 1 -th batch 0 -th task
# Accuracy:  99.9
# 2 -th batch 0 -th task
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.07921211421489716 ; Error bound warning:  0.5431730151176453 ; Error bound drift:  0.5979205369949341
# Status: STABLE
# 3 -th batch 0 -th task
# A cut point is detected cut:  500
# ...

# %%
# %run ADCN-splitCIFAR10-multiTask.ipynb
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  55000
# Number of unlabeled data batch:  55
# Number of task:  5
# Number of labeled data per task:  1000
# Number of unlabeled data per task:  10000
# Number of unlabeled data batch per task:  10
# Number of unlabeled data test:  5000
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# ...
