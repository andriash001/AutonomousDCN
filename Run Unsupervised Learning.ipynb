# %%
# %run ADCN-MNIST.ipynb
# Out:
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  65000
# Number of unlabeled data batch:  65
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# ...

# %%
# %run ADCN-KMNIST.ipynb
# Out:
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  65000
# Number of unlabeled data batch:  65
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
#
#
# Cluster initialization phase is started
# A cluster was created containing  2566  centroids
# 0 -th batch
# Accuracy:  77.6
# 1 -th batch
# A cut point is detected cut:  500
# ...

# %%
# %run ADCN-FashionMNIST.ipynb
# Out:
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  65000
# Number of unlabeled data batch:  65
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  2259  centroids
# 0 -th batch
# Accuracy:  71.8
# 1 -th batch
# A cut point is detected cut:  500
# ...

# %%
# %run ADCN-CIFAR10.ipynb
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  55000
# Number of unlabeled data batch:  55
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# ...

# %%
# %run ADCN-SEA.ipynb
# Out:
# Number of output:  2
# Number of labeled data:  1000
# Number of unlabeled data:  99000
# Number of unlabeled data batch:  99
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  160  centroids
# 0 -th batch
# Accuracy:  81.0
# 1 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.12502022087574005 ; Error bound warning:  0.2772798538208008 ; Error bound drift:  0.30522745847702026
# Status: STABLE
# --- Prune node ---
# 2 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.028784966096282005 ; Error bound warning:  0.2769361436367035 ; Error bound drift:  0.30484917759895325
# Status: STABLE
# 3 -th batch
# A cut point is detected cut:  500
# ...

# %%
# %run ADCN-Hyperplane.ipynb
# Out:
# Number of output:  2
# Number of labeled data:  1000
# Number of unlabeled data:  119000
# Number of unlabeled data batch:  119
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  66  centroids
# 0 -th batch
# Accuracy:  77.3
# 1 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.011568641290068626 ; Error bound warning:  0.11219433695077896 ; Error bound drift:  0.12350264191627502
# Status: STABLE
# 2 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.005527956411242485 ; Error bound warning:  0.11060452461242676 ; Error bound drift:  0.12175258249044418
# Status: STABLE
# 3 -th batch
# A cut point is detected cut:  500
# ...

# %%
# %run ADCN-creditcard.ipynb
# Out:
# Number of output:  2
# Number of labeled data:  1000
# Number of unlabeled data:  29000
# Number of unlabeled data batch:  29
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# +++ Grow node +++
# --- Prune node ---
# +++ Grow node +++
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  121  centroids
# 0 -th batch
# Accuracy:  95.7
# 1 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.005914643406867981 ; Error bound warning:  0.047039300203323364 ; Error bound drift:  0.051780492067337036
# Status: STABLE
# 2 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.003920892719179392 ; Error bound warning:  0.04692883417010307 ; Error bound drift:  0.05165887996554375
# Status: STABLE
# 3 -th batch
# A cut point is detected cut:  500
# ...
